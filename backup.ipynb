-- %% [markdown]
-- # [library]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [library]    Script Date: 10/28/2023 10:05:25 PM ******/
CREATE DATABASE [library]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'library', FILENAME = N'E:\apps\sql\sql-app\MSSQL16.SQLEXPRESS\MSSQL\DATA\library.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'library_log', FILENAME = N'E:\apps\sql\sql-app\MSSQL16.SQLEXPRESS\MSSQL\DATA\library_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [library] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [library].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [library] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [library] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [library] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [library] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [library] SET ARITHABORT OFF 
GO
ALTER DATABASE [library] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [library] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [library] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [library] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [library] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [library] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [library] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [library] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [library] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [library] SET  ENABLE_BROKER 
GO
ALTER DATABASE [library] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [library] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [library] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [library] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [library] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [library] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [library] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [library] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [library] SET  MULTI_USER 
GO
ALTER DATABASE [library] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [library] SET DB_CHAINING OFF 
GO
ALTER DATABASE [library] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [library] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [library] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [library] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [library] SET QUERY_STORE = ON
GO
ALTER DATABASE [library] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[ChuDe]

-- %%
USE [library]
GO

-- %%
/****** Object:  Table [dbo].[ChuDe]    Script Date: 10/28/2023 10:05:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ChuDe](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[tenchude] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[dbosach]

-- %%
/****** Object:  Table [dbo].[dbosach]    Script Date: 10/28/2023 10:05:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[dbosach](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[chieudai] [int] NULL,
	[chieurong] [int] NULL,
	[chudeid] [int] NULL,
	[dinhdang] [nvarchar](100) NULL,
	[dongia] [int] NULL,
	[hinhanh] [nvarchar](200) NULL,
	[nhaxuatbanid] [int] NULL,
	[soluong] [int] NULL,
	[sotrang] [int] NULL,
	[tacgiaid] [int] NULL,
	[tensach] [nvarchar](255) NULL,
	[DuocMuon] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
INSERT INTO [library].[dbo].[dbosach] ([chieudai], [chieurong], [chudeid], [dinhdang], [dongia], [hinhanh], [nhaxuatbanid], [soluong], [sotrang], [tacgiaid], [tensach], [DuocMuon])
VALUES (100, 150, 4, N'PDF', 20, N'sach 1.jpg', 1, 100, 300, 1, N'Aaron-James', 1),
(100, 150, 5, N'PDF', 20, N'sach 3.jpg', 2, 100, 300, 1, N'Aaran', 1),
(100, 150, 5, N'PDF', 20, N'sach 3.jpg', 3, 100, 300, 1, N'Aaryan', 1),
(100, 150, 2, N'PDF', 20, N'sach 2.jpg', 1, 100, 300, 2, N'Aarman', 1),
(100, 150, 2, N'PDF', 20, N'sach 2.jpg', 2, 100, 300, 1, N'Aaron', 1),
(100, 150, 4, N'PDF', 20, N'sach 2.jpg', 1, 100, 300, 2, N'Aayan', 1),
(100, 150, 3, N'PDF', 20, N'sach 2.jpg', 1, 100, 300, 1, N'Aaron', 1),
(100, 150, 1, N'PDF', 20, N'sach 1.jpg', 2, 100, 300, 3, N'Aaren', 1),
(100, 150, 5, N'PDF', 20, N'sach 3.jpg', 2, 100, 300, 2, N'Aaryan', 1),
(100, 150, 4, N'PDF', 20, N'sach 3.jpg', 3, 100, 300, 2, N'Aaryn', 1);

-- %% [markdown]
-- # [dbo].[NhanXet]

-- %%
/****** Object:  Table [dbo].[NhanXet]    Script Date: 10/28/2023 10:05:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NhanXet](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[sachid] [int] NULL,
	[tieude] [nvarchar](50) NULL,
	[userid] [int] NULL,
	[ngaydang] [datetime] NULL,
	[rating] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NhaXuatBan]

-- %%
/****** Object:  Table [dbo].[NhaXuatBan]    Script Date: 10/28/2023 10:05:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NhaXuatBan](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[tennhaxuatban] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PhieuMuon]

-- %%
/****** Object:  Table [dbo].[PhieuMuon]    Script Date: 10/28/2023 10:05:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PhieuMuon](
	[id] [int] NOT NULL,
	[ngaymuon] [datetime] NULL,
	[userid] [int] NULL,
	[ngaytra] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Quyen]

-- %%
/****** Object:  Table [dbo].[Quyen]    Script Date: 10/28/2023 10:05:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Quyen](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[tenquyen] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SachMuon]

-- %%
/****** Object:  Table [dbo].[SachMuon]    Script Date: 10/28/2023 10:05:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SachMuon](
	[sachmuonid] [int] NOT NULL,
	[sachid] [int] NULL,
	[soluong] [int] NULL,
	[phieumuonid] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[sachmuonid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TacGia]

-- %%
/****** Object:  Table [dbo].[TacGia]    Script Date: 10/28/2023 10:05:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TacGia](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[tentacgia] [nvarchar](225) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaiKhoan]

-- %%
/****** Object:  Table [dbo].[TaiKhoan]    Script Date: 10/28/2023 10:05:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaiKhoan](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[username] [nvarchar](256) NULL,
	[password] [varchar](255) NULL,
	[gioitinh] [bit] NULL,
	[ngaysinh] [datetime] NULL,
	[bikhoa] [int] NULL,
	[quyen] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__dbosach__DuocMuo__5CD6CB2B]

-- %%
ALTER TABLE [dbo].[dbosach] ADD  DEFAULT ((1)) FOR [DuocMuon]
GO

-- %% [markdown]
-- # [DF__SachMuon__soluon__70DDC3D8]

-- %%
ALTER TABLE [dbo].[SachMuon] ADD  DEFAULT ((0)) FOR [soluong]
GO

-- %% [markdown]
-- # [DF__TaiKhoan__gioiti__571DF1D5]

-- %%
ALTER TABLE [dbo].[TaiKhoan] ADD  DEFAULT ((0)) FOR [gioitinh]
GO

-- %% [markdown]
-- # [DF__TaiKhoan__ngaysi__5812160E]

-- %%
ALTER TABLE [dbo].[TaiKhoan] ADD  DEFAULT ('0001-01-01T00:00:00.000') FOR [ngaysinh]
GO

-- %% [markdown]
-- # [DF__TaiKhoan__bikhoa__59063A47]

-- %%
ALTER TABLE [dbo].[TaiKhoan] ADD  DEFAULT ((0)) FOR [bikhoa]
GO

-- %% [markdown]
-- # [DF__TaiKhoan__quyen__59FA5E80]

-- %%
ALTER TABLE [dbo].[TaiKhoan] ADD  DEFAULT ((0)) FOR [quyen]
GO

-- %% [markdown]
-- # [FK__dbosach__chudeid__5DCAEF64]

-- %%
ALTER TABLE [dbo].[dbosach]  WITH CHECK ADD FOREIGN KEY([chudeid])
REFERENCES [dbo].[ChuDe] ([id])
GO

-- %% [markdown]
-- # [FK__dbosach__nhaxuat__5EBF139D]

-- %%
ALTER TABLE [dbo].[dbosach]  WITH CHECK ADD FOREIGN KEY([nhaxuatbanid])
REFERENCES [dbo].[NhaXuatBan] ([id])
GO

-- %% [markdown]
-- # [FK__dbosach__tacgiai__5FB337D6]

-- %%
ALTER TABLE [dbo].[dbosach]  WITH CHECK ADD FOREIGN KEY([tacgiaid])
REFERENCES [dbo].[TacGia] ([id])
GO

-- %% [markdown]
-- # [FK__NhanXet__sachid__66603565]

-- %%
ALTER TABLE [dbo].[NhanXet]  WITH CHECK ADD FOREIGN KEY([sachid])
REFERENCES [dbo].[dbosach] ([id])
GO

-- %% [markdown]
-- # [FK__NhanXet__userid__6754599E]

-- %%
ALTER TABLE [dbo].[NhanXet]  WITH CHECK ADD FOREIGN KEY([userid])
REFERENCES [dbo].[TaiKhoan] ([id])
GO

-- %% [markdown]
-- # [FK__PhieuMuon__useri__6E01572D]

-- %%
ALTER TABLE [dbo].[PhieuMuon]  WITH CHECK ADD FOREIGN KEY([userid])
REFERENCES [dbo].[TaiKhoan] ([id])
GO

-- %% [markdown]
-- # [FK__SachMuon__phieum__71D1E811]

-- %%
ALTER TABLE [dbo].[SachMuon]  WITH CHECK ADD FOREIGN KEY([phieumuonid])
REFERENCES [dbo].[PhieuMuon] ([id])
GO

-- %% [markdown]
-- # [FK__SachMuon__sachid__72C60C4A]

-- %%
ALTER TABLE [dbo].[SachMuon]  WITH CHECK ADD FOREIGN KEY([sachid])
REFERENCES [dbo].[dbosach] ([id])
GO

-- %% [markdown]
-- # [library]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [library] SET  READ_WRITE 
GO
